# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("https://data.wprdc.org/datastore/dump/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f")
df.columns = df.columns.str.lower()

crime = df['incidentneighborhood'].value_counts()

crime_sorted = crime_counts.sort_values(ascending=True)
best10 = crime_sorted.head(10)
worst10 = crime.head(10)


plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
best10.plot(kind='bar',color='blue')
plt.title("Top 10 safest neighborhoods in Pittsburgh")
plt.xlabel("Neighborhood")
plt.ylabel("Number of Incidents")
plt.xticks(rotation=45, ha='right')


plt.subplot(1,2,2)
worst10.plot(kind='bar', color='red')
plt.title("Top 10 most dangerous neighborhoods in Pittsburgh")
plt.xlabel("Neighborhood")
plt.ylabel("Number of Incidents")
plt.xticks(rotation=45, ha='right')

plt.show()


crimeList = pd.Series(crime)

crimeList
# Out:
# incidentneighborhood
# Central Business District    4440
# South Side Flats             3497
# Carrick                      2352
# East Allegheny               2217
# Homewood South               2090
#                              ...
# Ridgemont                      37
# Central Northside              23
# Mt. Oliver Boro                18
# Troy Hill-Herrs Island          6
# Mt. Oliver Neighborhood         2
# Name: count, Length: 98, dtype: int64
