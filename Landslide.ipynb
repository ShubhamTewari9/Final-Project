# %% [markdown]
# My metric for the best neighborhood in Pittsburgh is risk of **Landslides**
#
# I used the City of Pittsbrugh's "Landslide prone areas" dataset, which along with the CSV file, has a helpful map to visualize. Unfortunately nothing in the original CSV file has anything to do with the location, and I had to use the map to edit a copy of the CSV for data usage purposes.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

landslide = pd.read_csv("Landslide.csv",sep="\t")

# %% [markdown]
# ![PITTSBURGH-NEIGHBORHOODS.webp](attachment:e77bc5f6-cc34-4578-a1c8-dea3252fff0e.webp)

# %% [markdown]
# ![image.png](attachment:418c0dbd-3a16-4b00-a414-13edfe60f3cf.png)

# %% [markdown]
# The first map is what I used to decide what neighborhoods that the blue areas on the second map mostly resided in. I then entered this into the CSV file under a new column called area, and will use this in the data visualization
